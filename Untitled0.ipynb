# %%
# !rm -rf Gestion_Bibl
# !git clone https://github.com/TON_UTILISATEUR/Gestion_Bibl.git
# Out:
# Cloning into 'Gestion_Bibl'...
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# Clone ton dépôt GitHub dans l'environnement Colab
# !git clone https://github.com/SAMACH88/Gestion_Bibl
# Out:
# Cloning into 'Gestion_Bibl'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 44 (delta 14), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (44/44), 20.33 KiB | 10.16 MiB/s, done.
# Resolving deltas: 100% (14/14), done.

# %%
import sys
sys.path.append('/content/Gestion_Bibl')

# %%
import sys
sys.path.append('/content/Gestion_Bibl')

from livre import Livre
from utilisateur import Utilisateur
from bibliotheque import Bibliotheque

# test
livre1 = Livre("Python Pro", "Prof Zaid")
utilisateur1 = Utilisateur("Sara", 2)

biblio = Bibliotheque()
biblio.ajouter_livre(livre1)
biblio.ajouter_utilisateur(utilisateur1)
biblio.afficher_livres()
biblio.afficher_utilisateurs()
# Out:
# Liste des livres :
# Python Pro par Prof Zaid
# Liste des utilisateurs :
# Sara (ID: 2)
