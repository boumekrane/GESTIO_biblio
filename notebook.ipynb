# %%
# 1. Monter Google Drive
from google.colab import drive
drive.mount('/content/drive/MyDrive/Gestion_Bib')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-1d6cc92fa925> in <cell line: 0>()
#       1 # 1. Monter Google Drive
#       2 from google.colab import drive
# ----> 3 drive.mount('/content/drive/MyDrive/Gestion_Bib')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     202     normed = _os.path.normpath(mountpoint)
# ...

# %%
# 2. Ajouter le chemin du dossier contenant les fichiers .py
import sys
sys.path.append('/content/drive/MyDrive/Gestion_Bib')  # ← adapte ce chemin

# 3. Importer les modules
from livre import Livre
from utilisateur import Utilisateur
from bibliotheque import Bibliotheque

# 4. Tester le code
livre1 = Livre("Python Facile", "Alice")
print(livre1)
# Simulation de main.py
livre1 = Livre("Python Facile", "Alice")
livre2 = Livre("Machine Learning", "Bob")

utilisateur1 = Utilisateur("Sami", 1)
utilisateur2 = Utilisateur("Nadia", 2)

biblio = Bibliotheque()
biblio.ajouter_livre(livre1)
biblio.ajouter_livre(livre2)
biblio.ajouter_utilisateur(utilisateur1)
biblio.ajouter_utilisateur(utilisateur2)

biblio.afficher_livres()
biblio.afficher_utilisateurs()

utilisateur1.emprunter_livre(livre1)
utilisateur2.emprunter_livre(livre2)
utilisateur1.retourner_livre(livre1)
